# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
# %matplotlib inline
from matplotlib.pyplot import figure
from pprint import pprint

# %%
# Import our data into pandas from CSV
Data_source = '../Shadi-Charts/11_country.csv'
file_df = pd.read_csv(Data_source)

file_df
# Out:
#      Unnamed: 0                              Song Name  Danceability  Energy  \
# 0             0                            Without You          0.67    0.70
# 1             1                                     句號          0.72    0.48
# 2             2                                  Yummy          0.66    0.52
# 3             3                           Dance Monkey          0.82    0.59
# 4             4                      Why You Gonna Lie          0.77    0.76
# ..          ...                                    ...           ...     ...
# 545         545              No Guidance (feat. Drake)          0.70    0.45
# 546         546             Ballin' (with Roddy Ricch)          0.81    0.55
# 547         547                      Never Really Over          0.77    0.88
# 548         548  Own It (feat. Ed Sheeran & Burna Boy)          0.82    0.78
# 549         549                             Nana Thula          0.77    0.52
#
# ...

# %%
#Clean and re-arrange the columns
data_df=file_df[['Country','Danceability','Loudness','Valence','Speechiness','Acousticness','Instramentalness','Tempo','Duration (ms)']]
# clean a colum name
data_df=data_df.rename(columns={"Duration (ms)":"Duration"})

data_df
# Out:
#           Country  Danceability  Loudness  Valence  Speechiness  Acousticness  \
# 0          Taiwan          0.67     -4.61     0.29         0.09          0.57
# 1          Taiwan          0.72     -8.55     0.46         0.06          0.25
# 2          Taiwan          0.66     -6.55     0.49         0.11          0.40
# 3          Taiwan          0.82     -6.40     0.51         0.09          0.69
# 4          Taiwan          0.77     -3.73     0.74         0.10          0.76
# ..            ...           ...       ...      ...          ...           ...
# 545  South Africa          0.70     -6.76     0.14         0.15          0.12
# 546  South Africa          0.81     -6.68     0.24         0.07          0.39
# 547  South Africa          0.77     -4.79     0.39         0.06          0.19
# 548  South Africa          0.82     -4.18     0.36         0.11          0.01
# 549  South Africa          0.77    -13.82     0.59         0.05          0.00
#
# ...

# %%
# Calculate the mean for all musical features per country

pd.options.display.float_format = '{:,.2f}'.format
#Group by country and calculate mean

Danceability_mean=data_df.groupby(['Country']).mean()
Danceability_mean
# Out:
#               Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Country
# Australia             0.69     -6.23     0.51         0.09          0.25
# Brazil                0.69     -5.00     0.65         0.13          0.35
# France                0.73     -6.78     0.53         0.13          0.35
# HongKong              0.62     -7.12     0.45         0.07          0.40
# India                 0.66     -5.52     0.52         0.08          0.33
# Japan                 0.52     -4.36     0.53         0.06          0.21
# Malaysia              0.67     -7.00     0.49         0.10          0.36
# South Africa          0.70     -6.88     0.46         0.09          0.26
# Taiwan                0.63     -7.49     0.40         0.07          0.39
# UK                    0.70     -6.78     0.48         0.14          0.25
# US                    0.72     -6.64     0.45         0.16          0.23
#
#               Instramentalness  Tempo   Duration
# Country
# ...

# %%
# Comparing Mean for different Audio features between countries

# Danceability

#retrive columns
data_df_Danceability=data_df[["Country","Danceability"]]

#Group by country and calculate mean
Danceability_mean=data_df_Danceability.groupby(['Country']).mean()


#Picture size
plt.figure(figsize=(3.841,10),dpi=100)

# Create a bar chart based off of the mean by country
Danceability_mean_chart = Danceability_mean.plot(kind='bar',color=('orange'))


# Set the xlabel and ylabel using class methods
Danceability_mean_chart.set_xlabel("Country")
Danceability_mean_chart.set_ylabel("Average Danceability")

plt.ylim(0.3, 0.8)
plt.tight_layout()
plt.savefig("Danceability.png", dpi=1000)
plt.show()

# %%
# Comparing Mean for diffirent Audio features between countries

# Loudness
#retrive columns

data_df_Loudness=data_df[["Country","Loudness"]]

#Group by country and calculate mean
Loudness_mean=data_df_Loudness.groupby(['Country']).mean()
Loudness_mean


# Create a bar chart based off of the mean by country
Loudness_mean_chart = Loudness_mean.plot(kind='bar')
plt.ylim(-3, -8)

# Set the xlabel and ylabel using class methods
Loudness_mean_chart.set_xlabel("Country")
Loudness_mean_chart.set_ylabel("Average Loudness")


plt.tight_layout()
plt.savefig("Loudness.png", dpi=1000)
plt.show()

# %%
# Comparing Mean for diffirent Audio features between countries

# Acousticness
#retrive columns
data_df_Acousticness=data_df[["Country","Acousticness"]]

#Group by country and calculate mean
Acousticness_mean=data_df_Acousticness.groupby(['Country']).mean()


#Pic Size
plt.figure(figsize=(19.20,10.80))

# Create a bar chart based off of the mean by country
Acousticness_mean_chart = Acousticness_mean.plot(kind='bar',color=('g'))

# Set the xlabel and ylabel using class methods
Acousticness_mean_chart.set_xlabel("Country")
Acousticness_mean_chart.set_ylabel("Average Acousticness")


plt.ylim(0.05, 0.6)
plt.tight_layout()
plt.savefig("Acousticness.png", dpi=1000)
plt.show()

# %%
# Comparing Mean for diffirent Audio features between countries

# Tempo
#retrive columns

data_df_Tempo=data_df[["Country","Tempo"]]
#Group by country and calculate mean
Tempo_mean=data_df_Tempo.groupby(['Country']).mean()

# Double check the data
Tempo_mean

# picture size
plt.figure(figsize=(19.20,10.80))

# Create a bar chart based off of the mean by country
Tempo_mean_chart = Tempo_mean.plot(kind='bar',color=('pink'))

# Set the xlabel and ylabel using class methods
Tempo_mean_chart.set_xlabel("Country")
Tempo_mean_chart.set_ylabel("Average Tempo")

#picture resolution
plt.ylim(20, 150)
plt.tight_layout()
plt.savefig("Tempo.png", dpi=1000)
plt.show()

# %%
# Comparing Mean for diffirent Audio features between countries
#Duration
#retrive columns
plt.figure(figsize=(19.20,10.80))
data_df_Duration=data_df[["Country","Duration"]]
#Group by country and calculate mean

Duration_mean=data_df_Duration.groupby(['Country']).mean()



# Create a bar chart based off of the mean by country
Duration_mean_chart = Duration_mean.plot(kind='bar',color=('red'))
# Set the xlabel and ylabel using class methods
Duration_mean_chart.set_xlabel("Country")
Duration_mean_chart.set_ylabel("Average Duration")


plt.ylim(140000, 260000)
plt.tight_layout()
plt.savefig("Duration.png", dpi=1000)
plt.show()

# %%
# Comparing Mean for diffirent Audio features between countries

#Valence
#retrive columns
plt.figure(figsize=(19.20,10.80))
data_df_Valence=data_df[["Country","Valence"]]
#Group by country and calculate meanValence

Valence_mean=data_df_Valence.groupby(['Country']).mean()


# Create a bar chart based off of the mean by country
Valence_mean_chart = Valence_mean.plot(kind='bar',color=('purple'))
# Set the xlabel and ylabel using class methods
Valence_mean_chart.set_xlabel("Country")
Valence_mean_chart.set_ylabel("Average Valence")

plt.ylim(0.3, 0.7)
plt.tight_layout()
plt.savefig("Valence.png", dpi=1000)
plt.show()

# %%
#Create a Box plot for Danceability factor by country
np.random.seed(1234)

# boxplot = data_df.boxplot(by='Country',column=['Danceability'], grid=False)
fig=data_df.boxplot(column='Danceability', by='Country', ax=None, fontsize=12,patch_artist=True, rot=45, grid=False, 
                    figsize=(11,5), layout=None)
colors = ['b', 'y', 'm', 'c', 'g', 'b', 'r', 'k','p','w','yellow']
for patch in fig['boxes']:
       patch.set(facecolor=fill_color)
#**kwargs=False
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-0e77b7363bcb> in <module>
#       6                     figsize=(11,5), layout=None)
#       7 colors = ['b', 'y', 'm', 'c', 'g', 'b', 'r', 'k','p','w','yellow']
# ----> 8 for patch in fig['boxes']:
#       9        patch.set(facecolor=fill_color)
#      10 #**kwargs=False
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
#calculate the correlation between all audio features (excl.countries)
audio_corr=data_df.corr(method ='pearson') 
audio_corr
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00     -0.04     0.44         0.19         -0.18
# Loudness                 -0.04      1.00     0.37        -0.10         -0.37
# Valence                   0.44      0.37     1.00         0.09         -0.16
# Speechiness               0.19     -0.10     0.09         1.00         -0.10
# Acousticness             -0.18     -0.37    -0.16        -0.10          1.00
# Instramentalness         -0.08     -0.42    -0.20         0.01          0.25
# Tempo                    -0.17     -0.02    -0.08         0.14         -0.06
# Duration                 -0.21     -0.20    -0.22        -0.10          0.10
#
#                   Instramentalness  Tempo  Duration
# Danceability                 -0.08  -0.17     -0.21
# Loudness                     -0.42  -0.02     -0.20
# Valence                      -0.20  -0.08     -0.22
# Speechiness                   0.01   0.14     -0.10
# ...

# %%
country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]

for i in country:
    data_correlation= data_df.loc[data_df['Country']=="i"]
   
    
data_correlation
# Out:
# Empty DataFrame
# Columns: [Country, Danceability, Loudness, Valence, Speechiness, Acousticness, Instramentalness, Tempo, Duration]
# Index: []

# %%
#Pick "US" to claculate correlation
data_US_correlation= data_df.loc[data_df['Country']=="US"]
data_US_correlation.head()
# Out:
#     Country  Danceability  Loudness  Valence  Speechiness  Acousticness  \
# 200      US          0.90     -6.69     0.64         0.06          0.10
# 201      US          0.68     -5.83     0.51         0.48          0.07
# 202      US          0.62     -5.62     0.46         0.15          0.05
# 203      US          0.77     -3.91     0.84         0.37          0.19
# 204      US          0.79    -12.92     0.24         0.17          0.85
#
#      Instramentalness  Tempo  Duration
# 200              0.00 116.97    196653
# 201              0.00 142.04    237735
# 202              0.00 116.73    163636
# 203              0.00 126.77    159715
# 204              0.13 174.09    342040

# %%
#calculate the correlation between all audio features for "US"
# the columns using pearson method 
data_US_correlation.corr(method ='pearson')
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00     -0.04     0.35         0.31         -0.14
# Loudness                 -0.04      1.00     0.41         0.04         -0.41
# Valence                   0.35      0.41     1.00         0.31         -0.03
# Speechiness               0.31      0.04     0.31         1.00         -0.27
# Acousticness             -0.14     -0.41    -0.03        -0.27          1.00
# Instramentalness         -0.01     -0.59    -0.16        -0.01          0.46
# Tempo                    -0.15      0.01    -0.20         0.23         -0.17
# Duration                 -0.08     -0.45    -0.21        -0.17          0.37
#
#                   Instramentalness  Tempo  Duration
# Danceability                 -0.01  -0.15     -0.08
# Loudness                     -0.59   0.01     -0.45
# Valence                      -0.16  -0.20     -0.21
# Speechiness                  -0.01   0.23     -0.17
# ...

# %%
# The pearson correlation between different features for US
x=data_US_correlation[['Danceability']]
y=data_US_correlation[['Valence']]
plt.scatter(x,y, s=None, c='r', marker=None, cmap=None, norm=None, 
                                   vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors='r', plotnonfinite=False)
plt.xlabel('Danceability')
plt.ylabel('Valence')
plt.legend()

plt.ylim(-0.3, 0.7)
plt.tight_layout()
plt.savefig("USScatter.png", dpi=1000)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]
#Pick "US" to claculate correlation
data_Australia_correlation= data_df.loc[data_df['Country']=="Australia"]
data_Australia_correlation.head()

data_Australia_correlation.corr(method ='pearson')
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00     -0.09     0.51         0.08         -0.15
# Loudness                 -0.09      1.00     0.32        -0.27         -0.44
# Valence                   0.51      0.32     1.00         0.02         -0.25
# Speechiness               0.08     -0.27     0.02         1.00         -0.01
# Acousticness             -0.15     -0.44    -0.25        -0.01          1.00
# Instramentalness          0.04     -0.62    -0.23         0.14          0.43
# Tempo                    -0.10     -0.29    -0.28         0.30         -0.02
# Duration                  0.12     -0.42    -0.25         0.29          0.29
#
#                   Instramentalness  Tempo  Duration
# Danceability                  0.04  -0.10      0.12
# Loudness                     -0.62  -0.29     -0.42
# Valence                      -0.23  -0.28     -0.25
# Speechiness                   0.14   0.30      0.29
# ...

# %%
#country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]
#Pick "US" to claculate correlation
data_Brazil_correlation= data_df.loc[data_df['Country']=="Brazil"]
data_Brazil_correlation.head()

corr_Brazil=data_Brazil_correlation.corr(method ='pearson') 
corr_Brazil
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00      0.01     0.60        -0.22          0.02
# Loudness                  0.01      1.00     0.27        -0.21         -0.01
# Valence                   0.60      0.27     1.00        -0.24         -0.04
# Speechiness              -0.22     -0.21    -0.24         1.00          0.14
# Acousticness              0.02     -0.01    -0.04         0.14          1.00
# Instramentalness          0.11      0.14     0.07         0.08         -0.05
# Tempo                    -0.04      0.17     0.26         0.20         -0.14
# Duration                 -0.25     -0.17    -0.38        -0.01          0.22
#
#                   Instramentalness  Tempo  Duration
# Danceability                  0.11  -0.04     -0.25
# Loudness                      0.14   0.17     -0.17
# Valence                       0.07   0.26     -0.38
# Speechiness                   0.08   0.20     -0.01
# ...

# %%
#country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]
#Pick "US" to claculate correlation
data_France_correlation= data_df.loc[data_df['Country']=="France"]
data_France_correlation.head()

corr_France=data_France_correlation.corr(method ='pearson') 
corr_France
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00      0.07     0.36        -0.18         -0.08
# Loudness                  0.07      1.00     0.34         0.03         -0.20
# Valence                   0.36      0.34     1.00        -0.13         -0.15
# Speechiness              -0.18      0.03    -0.13         1.00         -0.08
# Acousticness             -0.08     -0.20    -0.15        -0.08          1.00
# Instramentalness         -0.17     -0.30    -0.19        -0.09          0.07
# Tempo                    -0.28     -0.17    -0.27        -0.07         -0.08
# Duration                 -0.31     -0.22    -0.07         0.07          0.21
#
#                   Instramentalness  Tempo  Duration
# Danceability                 -0.17  -0.28     -0.31
# Loudness                     -0.30  -0.17     -0.22
# Valence                      -0.19  -0.27     -0.07
# Speechiness                  -0.09  -0.07      0.07
# ...

# %%
#country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]
#Pick "US" to claculate correlation
data_HongKong_correlation= data_df.loc[data_df['Country']=="HongKong"]
data_HongKong_correlation.head()

corr_HongKong=data_HongKong_correlation.corr(method ='pearson') 
corr_HongKong
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00      0.06     0.55         0.22         -0.42
# Loudness                  0.06      1.00     0.39        -0.15         -0.46
# Valence                   0.55      0.39     1.00         0.09         -0.24
# Speechiness               0.22     -0.15     0.09         1.00         -0.19
# Acousticness             -0.42     -0.46    -0.24        -0.19          1.00
# Instramentalness          0.13     -0.52    -0.18         0.18          0.25
# Tempo                    -0.27     -0.15    -0.31         0.08          0.07
# Duration                 -0.26     -0.42    -0.36        -0.01          0.39
#
#                   Instramentalness  Tempo  Duration
# Danceability                  0.13  -0.27     -0.26
# Loudness                     -0.52  -0.15     -0.42
# Valence                      -0.18  -0.31     -0.36
# Speechiness                   0.18   0.08     -0.01
# ...

# %%
#country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]
#Pick "US" to claculate correlation
data_India_correlation= data_df.loc[data_df['Country']=="India"]
data_India_correlation.head()

corr_India=data_India_correlation.corr(method ='pearson') 
corr_India
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00      0.22     0.43         0.28         -0.49
# Loudness                  0.22      1.00     0.32        -0.04         -0.33
# Valence                   0.43      0.32     1.00         0.16         -0.06
# Speechiness               0.28     -0.04     0.16         1.00         -0.33
# Acousticness             -0.49     -0.33    -0.06        -0.33          1.00
# Instramentalness          0.19      0.34     0.09        -0.07         -0.18
# Tempo                    -0.45      0.04    -0.09         0.07         -0.10
# Duration                 -0.65     -0.12    -0.21        -0.18          0.35
#
#                   Instramentalness  Tempo  Duration
# Danceability                  0.19  -0.45     -0.65
# Loudness                      0.34   0.04     -0.12
# Valence                       0.09  -0.09     -0.21
# Speechiness                  -0.07   0.07     -0.18
# ...

# %%
#country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]
#Pick "US" to claculate correlation
data_Japan_correlation= data_df.loc[data_df['Country']=="Japan"]
data_Japan_correlation.head()

corr_Japan=data_Japan_correlation.corr(method ='pearson') 
corr_Japan
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00      0.08     0.63         0.35         -0.07
# Loudness                  0.08      1.00     0.38        -0.26         -0.56
# Valence                   0.63      0.38     1.00         0.19         -0.31
# Speechiness               0.35     -0.26     0.19         1.00          0.00
# Acousticness             -0.07     -0.56    -0.31         0.00          1.00
# Instramentalness         -0.46     -0.62    -0.47        -0.06          0.42
# Tempo                    -0.03      0.05     0.06         0.05         -0.13
# Duration                  0.04      0.40    -0.09        -0.19         -0.21
#
#                   Instramentalness  Tempo  Duration
# Danceability                 -0.46  -0.03      0.04
# Loudness                     -0.62   0.05      0.40
# Valence                      -0.47   0.06     -0.09
# Speechiness                  -0.06   0.05     -0.19
# ...

# %%
#country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]
#Pick "US" to claculate correlation
data_Malaysia_correlation= data_df.loc[data_df['Country']=="Malaysia"]
data_Malaysia_correlation.head()

corr_Malaysia=data_Malaysia_correlation.corr(method ='pearson') 
corr_Malaysia
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00      0.15     0.66         0.11         -0.28
# Loudness                  0.15      1.00     0.35        -0.13         -0.55
# Valence                   0.66      0.35     1.00         0.16         -0.26
# Speechiness               0.11     -0.13     0.16         1.00         -0.12
# Acousticness             -0.28     -0.55    -0.26        -0.12          1.00
# Instramentalness          0.04     -0.39    -0.17         0.07          0.27
# Tempo                    -0.23      0.00    -0.23         0.12         -0.06
# Duration                 -0.01     -0.22     0.09         0.27          0.10
#
#                   Instramentalness  Tempo  Duration
# Danceability                  0.04  -0.23     -0.01
# Loudness                     -0.39   0.00     -0.22
# Valence                      -0.17  -0.23      0.09
# Speechiness                   0.07   0.12      0.27
# ...

# %%
# The pearson correlation between different features for Malaysia
x=data_Malaysia_correlation[['Danceability']]
y=data_Malaysia_correlation[['Valence']]
plt.scatter(x,y, s=None, c='g', marker=None, cmap=None, norm=None, 
                                   vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors='g', 
                                    plotnonfinite=False)
plt.xlabel('Danceability')
plt.ylabel('Valence')
plt.legend()

plt.ylim(-0.3, 0.7)
plt.tight_layout()
plt.savefig("MalaysiaScatter.png", dpi=1000)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]
#Pick "US" to claculate correlation
data_SouthAfrica_correlation= data_df.loc[data_df['Country']=="South Africa"]
data_SouthAfrica_correlation.head()

corr_SouthAfrica=data_SouthAfrica_correlation.corr(method ='pearson') 
corr_SouthAfrica
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00     -0.25     0.40         0.05         -0.12
# Loudness                 -0.25      1.00     0.31        -0.06         -0.19
# Valence                   0.40      0.31     1.00         0.09         -0.19
# Speechiness               0.05     -0.06     0.09         1.00          0.04
# Acousticness             -0.12     -0.19    -0.19         0.04          1.00
# Instramentalness          0.14     -0.70    -0.12         0.05          0.26
# Tempo                    -0.10     -0.07    -0.11         0.28          0.04
# Duration                  0.38     -0.67    -0.17        -0.04         -0.09
#
#                   Instramentalness  Tempo  Duration
# Danceability                  0.14  -0.10      0.38
# Loudness                     -0.70  -0.07     -0.67
# Valence                      -0.12  -0.11     -0.17
# Speechiness                   0.05   0.28     -0.04
# ...

# %%
#country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]
#Pick "US" to claculate correlation
data_Taiwan_correlation= data_df.loc[data_df['Country']=="Taiwan"]
data_Taiwan_correlation.head()

corr_Taiwan=data_Taiwan_correlation.corr(method ='pearson') 
corr_Taiwan
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00      0.14     0.57         0.33         -0.16
# Loudness                  0.14      1.00     0.23        -0.11         -0.32
# Valence                   0.57      0.23     1.00         0.32         -0.05
# Speechiness               0.33     -0.11     0.32         1.00         -0.13
# Acousticness             -0.16     -0.32    -0.05        -0.13          1.00
# Instramentalness          0.11     -0.42    -0.11         0.21          0.25
# Tempo                    -0.27      0.01    -0.18        -0.08         -0.21
# Duration                 -0.31     -0.38    -0.31        -0.23          0.13
#
#                   Instramentalness  Tempo  Duration
# Danceability                  0.11  -0.27     -0.31
# Loudness                     -0.42   0.01     -0.38
# Valence                      -0.11  -0.18     -0.31
# Speechiness                   0.21  -0.08     -0.23
# ...

# %%
#country=["Australia","Brazil","France","HongKong","India","Japan","Malaysia","South Africa","Taiwan","UK","US"]
#Pick "US" to claculate correlation
data_UK_correlation= data_df.loc[data_df['Country']=="UK"]
data_UK_correlation.head()

corr_UK=data_UK_correlation.corr(method ='pearson') 
corr_UK
# Out:
#                   Danceability  Loudness  Valence  Speechiness  Acousticness  \
# Danceability              1.00     -0.13     0.46         0.09         -0.09
# Loudness                 -0.13      1.00     0.23        -0.13         -0.46
# Valence                   0.46      0.23     1.00         0.01         -0.29
# Speechiness               0.09     -0.13     0.01         1.00         -0.06
# Acousticness             -0.09     -0.46    -0.29        -0.06          1.00
# Instramentalness          0.03     -0.60    -0.18         0.01          0.39
# Tempo                     0.03     -0.11     0.03         0.30         -0.06
# Duration                  0.03     -0.29    -0.25         0.24          0.33
#
#                   Instramentalness  Tempo  Duration
# Danceability                  0.03   0.03      0.03
# Loudness                     -0.60  -0.11     -0.29
# Valence                      -0.18   0.03     -0.25
# Speechiness                   0.01   0.30      0.24
# ...
