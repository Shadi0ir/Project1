# %%
import pandas as pd
import csv
import numpy as np

# %%
AU_df = pd.read_csv("CSV_Output/Australia_top_50_songs.csv")
IN_df = pd.read_csv("CSV_Output/India_top_50_songs.csv")
AU_df.head()
# Out:
#    Unnamed: 0        Song Name  Danceability  Energy  Key  Loudness  Mode  \
# 0           0          The Box         0.896   0.586   10    -6.687     0
# 1           1  Blinding Lights         0.513   0.796    1    -4.075     1
# 2           2  Don't Start Now         0.794   0.793   11    -4.521     0
# 3           3     Dance Monkey         0.824   0.588    6    -6.400     0
# 4           4          ROXANNE         0.621   0.601    6    -5.616     0
#
#    Speechiness  Acousticness  Instramentalness  Liveness  Valence    Tempo  \
# 0       0.0559       0.10400          0.000000    0.7900    0.642  116.971
# 1       0.0629       0.00147          0.000209    0.0938    0.345  171.017
# 2       0.0842       0.01250          0.000000    0.0952    0.677  123.941
# 3       0.0924       0.69200          0.000104    0.1490    0.513   98.027
# 4       0.1480       0.05220          0.000000    0.4600    0.457  116.735
#
#              Type                      ID  \
# 0  audio_features  0nbXyq5TXYPCO7pr3N8S4I
# 1  audio_features  0sf12qNH5qcw8qpgymFOqD
# 2  audio_features  6WrI0LAC5M1Rw2MnX2ZvEg
# 3  audio_features  2XU0oxnq2qxCpomAAuJY8K
# 4  audio_features  696DnlkuDOXcMAnKlTgXXK
#
#                                     URI  \
# 0  spotify:track:0nbXyq5TXYPCO7pr3N8S4I
# 1  spotify:track:0sf12qNH5qcw8qpgymFOqD
# 2  spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg
# 3  spotify:track:2XU0oxnq2qxCpomAAuJY8K
# 4  spotify:track:696DnlkuDOXcMAnKlTgXXK
#
#                                           Track Href  \
# 0  https://api.spotify.com/v1/tracks/0nbXyq5TXYPC...
# 1  https://api.spotify.com/v1/tracks/0sf12qNH5qcw...
# 2  https://api.spotify.com/v1/tracks/6WrI0LAC5M1R...
# 3  https://api.spotify.com/v1/tracks/2XU0oxnq2qxC...
# 4  https://api.spotify.com/v1/tracks/696DnlkuDOXc...
#
#                                         Analysis URL  Duration (ms)  \
# 0  https://api.spotify.com/v1/audio-analysis/0nbX...         196653
# 1  https://api.spotify.com/v1/audio-analysis/0sf1...         201573
# 2  https://api.spotify.com/v1/audio-analysis/6WrI...         183290
# 3  https://api.spotify.com/v1/audio-analysis/2XU0...         209438
# 4  https://api.spotify.com/v1/audio-analysis/696D...         163636
#
#    Time Signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               5

# %%
del AU_df["Unnamed: 0"]

# %%
AU_df.head()
# Out:
#          Song Name  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 0          The Box         0.896   0.586   10    -6.687     0       0.0559
# 1  Blinding Lights         0.513   0.796    1    -4.075     1       0.0629
# 2  Don't Start Now         0.794   0.793   11    -4.521     0       0.0842
# 3     Dance Monkey         0.824   0.588    6    -6.400     0       0.0924
# 4          ROXANNE         0.621   0.601    6    -5.616     0       0.1480
#
#    Acousticness  Instramentalness  Liveness  Valence    Tempo            Type  \
# 0       0.10400          0.000000    0.7900    0.642  116.971  audio_features
# 1       0.00147          0.000209    0.0938    0.345  171.017  audio_features
# 2       0.01250          0.000000    0.0952    0.677  123.941  audio_features
# 3       0.69200          0.000104    0.1490    0.513   98.027  audio_features
# 4       0.05220          0.000000    0.4600    0.457  116.735  audio_features
#
#                        ID                                   URI  \
# 0  0nbXyq5TXYPCO7pr3N8S4I  spotify:track:0nbXyq5TXYPCO7pr3N8S4I
# 1  0sf12qNH5qcw8qpgymFOqD  spotify:track:0sf12qNH5qcw8qpgymFOqD
# 2  6WrI0LAC5M1Rw2MnX2ZvEg  spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg
# 3  2XU0oxnq2qxCpomAAuJY8K  spotify:track:2XU0oxnq2qxCpomAAuJY8K
# 4  696DnlkuDOXcMAnKlTgXXK  spotify:track:696DnlkuDOXcMAnKlTgXXK
#
#                                           Track Href  \
# 0  https://api.spotify.com/v1/tracks/0nbXyq5TXYPC...
# 1  https://api.spotify.com/v1/tracks/0sf12qNH5qcw...
# 2  https://api.spotify.com/v1/tracks/6WrI0LAC5M1R...
# 3  https://api.spotify.com/v1/tracks/2XU0oxnq2qxC...
# 4  https://api.spotify.com/v1/tracks/696DnlkuDOXc...
#
#                                         Analysis URL  Duration (ms)  \
# 0  https://api.spotify.com/v1/audio-analysis/0nbX...         196653
# 1  https://api.spotify.com/v1/audio-analysis/0sf1...         201573
# 2  https://api.spotify.com/v1/audio-analysis/6WrI...         183290
# 3  https://api.spotify.com/v1/audio-analysis/2XU0...         209438
# 4  https://api.spotify.com/v1/audio-analysis/696D...         163636
#
#    Time Signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               5

# %%
AU_df.loc[:, 'Country'] = "Australia"

# %%
AU_df.head()
# Out:
#          Song Name  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 0          The Box         0.896   0.586   10    -6.687     0       0.0559
# 1  Blinding Lights         0.513   0.796    1    -4.075     1       0.0629
# 2  Don't Start Now         0.794   0.793   11    -4.521     0       0.0842
# 3     Dance Monkey         0.824   0.588    6    -6.400     0       0.0924
# 4          ROXANNE         0.621   0.601    6    -5.616     0       0.1480
#
#    Acousticness  Instramentalness  Liveness  Valence    Tempo            Type  \
# 0       0.10400          0.000000    0.7900    0.642  116.971  audio_features
# 1       0.00147          0.000209    0.0938    0.345  171.017  audio_features
# 2       0.01250          0.000000    0.0952    0.677  123.941  audio_features
# 3       0.69200          0.000104    0.1490    0.513   98.027  audio_features
# 4       0.05220          0.000000    0.4600    0.457  116.735  audio_features
#
#                        ID                                   URI  \
# 0  0nbXyq5TXYPCO7pr3N8S4I  spotify:track:0nbXyq5TXYPCO7pr3N8S4I
# 1  0sf12qNH5qcw8qpgymFOqD  spotify:track:0sf12qNH5qcw8qpgymFOqD
# 2  6WrI0LAC5M1Rw2MnX2ZvEg  spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg
# 3  2XU0oxnq2qxCpomAAuJY8K  spotify:track:2XU0oxnq2qxCpomAAuJY8K
# 4  696DnlkuDOXcMAnKlTgXXK  spotify:track:696DnlkuDOXcMAnKlTgXXK
#
#                                           Track Href  \
# 0  https://api.spotify.com/v1/tracks/0nbXyq5TXYPC...
# 1  https://api.spotify.com/v1/tracks/0sf12qNH5qcw...
# 2  https://api.spotify.com/v1/tracks/6WrI0LAC5M1R...
# 3  https://api.spotify.com/v1/tracks/2XU0oxnq2qxC...
# 4  https://api.spotify.com/v1/tracks/696DnlkuDOXc...
#
#                                         Analysis URL  Duration (ms)  \
# 0  https://api.spotify.com/v1/audio-analysis/0nbX...         196653
# 1  https://api.spotify.com/v1/audio-analysis/0sf1...         201573
# 2  https://api.spotify.com/v1/audio-analysis/6WrI...         183290
# 3  https://api.spotify.com/v1/audio-analysis/2XU0...         209438
# 4  https://api.spotify.com/v1/audio-analysis/696D...         163636
#
#    Time Signature    Country
# 0               4  Australia
# 1               4  Australia
# 2               4  Australia
# 3               4  Australia
# 4               5  Australia

# %%
IN_df.head()
# Out:
#                                            Song Name  Danceability  Energy  \
# 0       Illegal Weapon 2.0 (From "Street Dancer 3D")         0.805   0.919
# 1                  Muqabla (From "Street Dancer 3D")         0.804   0.913
# 2  Garmi (From "Street Dancer 3D") (feat. Varun D...         0.788   0.870
# 3                                              Yummy         0.662   0.519
# 4                                             Makhna         0.696   0.704
#
#    Key  Loudness  Mode  Speechiness  Acousticness  Instramentalness  Liveness  \
# 0    1    -1.294     1       0.0938        0.1010          0.003430    0.0598
# 1    0    -3.135     1       0.0933        0.0248          0.000028    0.3910
# 2    9    -5.217     1       0.1770        0.1230          0.000014    0.0692
# 3    9    -6.554     0       0.1060        0.4040          0.000000    0.1210
# 4    1    -7.876     1       0.0423        0.1670          0.000000    0.1550
#
#    Valence    Tempo            Type                      ID  \
# 0    0.494   94.993  audio_features  5fXslGZPI5Cco6PKHzlSL3
# 1    0.544  119.993  audio_features  28veUNu4veN0LOBVa0nFw8
# 2    0.884  109.974  audio_features  6q9XTgfWilsnyiFofvYrIF
# 3    0.495  145.841  audio_features  41L3O37CECZt3N7ziG2z7l
# 4    0.426  124.972  audio_features  0ZHILXmUaVSLEOCWxPQ1ga
#
#                                     URI  \
# 0  spotify:track:5fXslGZPI5Cco6PKHzlSL3
# 1  spotify:track:28veUNu4veN0LOBVa0nFw8
# 2  spotify:track:6q9XTgfWilsnyiFofvYrIF
# 3  spotify:track:41L3O37CECZt3N7ziG2z7l
# 4  spotify:track:0ZHILXmUaVSLEOCWxPQ1ga
#
#                                           Track Href  \
# 0  https://api.spotify.com/v1/tracks/5fXslGZPI5Cc...
# 1  https://api.spotify.com/v1/tracks/28veUNu4veN0...
# 2  https://api.spotify.com/v1/tracks/6q9XTgfWilsn...
# 3  https://api.spotify.com/v1/tracks/41L3O37CECZt...
# 4  https://api.spotify.com/v1/tracks/0ZHILXmUaVSL...
#
#                                         Analysis URL  Duration (ms)  \
# 0  https://api.spotify.com/v1/audio-analysis/5fXs...         188606
# 1  https://api.spotify.com/v1/audio-analysis/28ve...         176125
# 2  https://api.spotify.com/v1/audio-analysis/6q9X...         182739
# 3  https://api.spotify.com/v1/audio-analysis/41L3...         210427
# 4  https://api.spotify.com/v1/audio-analysis/0ZHI...         183000
#
#    Time Signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
IN_df.loc[:, 'Country'] = "India"

# %%
IN_df.head()
# Out:
#                                            Song Name  Danceability  Energy  \
# 0       Illegal Weapon 2.0 (From "Street Dancer 3D")         0.805   0.919
# 1                  Muqabla (From "Street Dancer 3D")         0.804   0.913
# 2  Garmi (From "Street Dancer 3D") (feat. Varun D...         0.788   0.870
# 3                                              Yummy         0.662   0.519
# 4                                             Makhna         0.696   0.704
#
#    Key  Loudness  Mode  Speechiness  Acousticness  Instramentalness  Liveness  \
# 0    1    -1.294     1       0.0938        0.1010          0.003430    0.0598
# 1    0    -3.135     1       0.0933        0.0248          0.000028    0.3910
# 2    9    -5.217     1       0.1770        0.1230          0.000014    0.0692
# 3    9    -6.554     0       0.1060        0.4040          0.000000    0.1210
# 4    1    -7.876     1       0.0423        0.1670          0.000000    0.1550
#
#    Valence    Tempo            Type                      ID  \
# 0    0.494   94.993  audio_features  5fXslGZPI5Cco6PKHzlSL3
# 1    0.544  119.993  audio_features  28veUNu4veN0LOBVa0nFw8
# 2    0.884  109.974  audio_features  6q9XTgfWilsnyiFofvYrIF
# 3    0.495  145.841  audio_features  41L3O37CECZt3N7ziG2z7l
# 4    0.426  124.972  audio_features  0ZHILXmUaVSLEOCWxPQ1ga
#
#                                     URI  \
# 0  spotify:track:5fXslGZPI5Cco6PKHzlSL3
# 1  spotify:track:28veUNu4veN0LOBVa0nFw8
# 2  spotify:track:6q9XTgfWilsnyiFofvYrIF
# 3  spotify:track:41L3O37CECZt3N7ziG2z7l
# 4  spotify:track:0ZHILXmUaVSLEOCWxPQ1ga
#
#                                           Track Href  \
# 0  https://api.spotify.com/v1/tracks/5fXslGZPI5Cc...
# 1  https://api.spotify.com/v1/tracks/28veUNu4veN0...
# 2  https://api.spotify.com/v1/tracks/6q9XTgfWilsn...
# 3  https://api.spotify.com/v1/tracks/41L3O37CECZt...
# 4  https://api.spotify.com/v1/tracks/0ZHILXmUaVSL...
#
#                                         Analysis URL  Duration (ms)  \
# 0  https://api.spotify.com/v1/audio-analysis/5fXs...         188606
# 1  https://api.spotify.com/v1/audio-analysis/28ve...         176125
# 2  https://api.spotify.com/v1/audio-analysis/6q9X...         182739
# 3  https://api.spotify.com/v1/audio-analysis/41L3...         210427
# 4  https://api.spotify.com/v1/audio-analysis/0ZHI...         183000
#
#    Time Signature Country
# 0               4   India
# 1               4   India
# 2               4   India
# 3               4   India
# 4               4   India

# %%
BA_df = pd.read_csv("CSV_Output/Brazil_top_50_songs.csv")
FR_df = pd.read_csv("CSV_Output/France_top_50_songs.csv")
HO_df = pd.read_csv("CSV_Output/Hong Kong_top_50_songs.csv")
JA_df = pd.read_csv("CSV_Output/Japan_top_50_songs.csv")
MA_df = pd.read_csv("CSV_Output/Malaysia_top_50_songs.csv")
SA_df = pd.read_csv("CSV_Output/South Africa_top_50_songs.csv")
TA_df = pd.read_csv("CSV_Output/Taiwan_top_50_songs.csv")
UK_df = pd.read_csv("CSV_Output/UK_top_50_songs.csv")

# %%
del BA_df["Unnamed: 0"]
del FR_df["Unnamed: 0"]
del HO_df["Unnamed: 0"]
del JA_df["Unnamed: 0"]
del MA_df["Unnamed: 0"]
del SA_df["Unnamed: 0"]
del TA_df["Unnamed: 0"]
del UK_df["Unnamed: 0"]

# %%
BA_df.loc[:, 'Country'] = "Brazil"
FR_df.loc[:, 'Country'] = "France"
HO_df.loc[:, 'Country'] = "HongKong"
JA_df.loc[:, 'Country'] = "Japan"
MA_df.loc[:, 'Country'] = "Malaysia"
SA_df.loc[:, 'Country'] = "South Africa"
TA_df.loc[:, 'Country'] = "Taiwan"
UK_df.loc[:, 'Country'] = "UK"

# %%
US_df = pd.read_csv("CSV_Output/US_top_50_songs.csv")

# %%
del US_df["Unnamed: 0"]

# %%
US_df.loc[:, 'Country'] = "US"

# %%
US_df.head()
# Out:
#                     Song Name  Danceability  Energy  Key  Loudness  Mode  \
# 0                     The Box         0.896   0.586   10    -6.687     0
# 1  Life Is Good (feat. Drake)         0.676   0.609    2    -5.831     0
# 2                     ROXANNE         0.621   0.601    6    -5.616     0
# 3                         BOP         0.769   0.787   11    -3.909     1
# 4                   Good News         0.794   0.320    1   -12.920     0
#
#    Speechiness  Acousticness  Instramentalness  Liveness  Valence    Tempo  \
# 0       0.0559        0.1040             0.000     0.790    0.642  116.971
# 1       0.4810        0.0706             0.000     0.152    0.508  142.037
# 2       0.1480        0.0522             0.000     0.460    0.457  116.735
# 3       0.3670        0.1890             0.000     0.129    0.836  126.770
# 4       0.1730        0.8530             0.134     0.112    0.241  174.088
#
#              Type                      ID  \
# 0  audio_features  0nbXyq5TXYPCO7pr3N8S4I
# 1  audio_features  5yY9lUy8nbvjM1Uyo1Uqoc
# 2  audio_features  696DnlkuDOXcMAnKlTgXXK
# 3  audio_features  6Ozh9Ok6h4Oi1wUSLtBseN
# 4  audio_features  3ClBKQkKoaUQ6UOhe2xlJK
#
#                                     URI  \
# 0  spotify:track:0nbXyq5TXYPCO7pr3N8S4I
# 1  spotify:track:5yY9lUy8nbvjM1Uyo1Uqoc
# 2  spotify:track:696DnlkuDOXcMAnKlTgXXK
# 3  spotify:track:6Ozh9Ok6h4Oi1wUSLtBseN
# 4  spotify:track:3ClBKQkKoaUQ6UOhe2xlJK
#
#                                           Track Href  \
# 0  https://api.spotify.com/v1/tracks/0nbXyq5TXYPC...
# 1  https://api.spotify.com/v1/tracks/5yY9lUy8nbvj...
# 2  https://api.spotify.com/v1/tracks/696DnlkuDOXc...
# 3  https://api.spotify.com/v1/tracks/6Ozh9Ok6h4Oi...
# 4  https://api.spotify.com/v1/tracks/3ClBKQkKoaUQ...
#
#                                         Analysis URL  Duration (ms)  \
# 0  https://api.spotify.com/v1/audio-analysis/0nbX...         196653
# 1  https://api.spotify.com/v1/audio-analysis/5yY9...         237735
# 2  https://api.spotify.com/v1/audio-analysis/696D...         163636
# 3  https://api.spotify.com/v1/audio-analysis/6Ozh...         159715
# 4  https://api.spotify.com/v1/audio-analysis/3ClB...         342040
#
#    Time Signature Country
# 0               4      US
# 1               4      US
# 2               5      US
# 3               4      US
# 4               4      US

# %%
AU_IN = pd.merge(AU_df,IN_df,how ='outer')

# %%
BA_FR = pd.merge(BA_df,FR_df,how ='outer')

# %%
HO_JA = pd.merge(HO_df,JA_df,how ='outer')

# %%
MA_SA = pd.merge(MA_df,SA_df,how ='outer')

# %%
TA_UK = pd.merge(TA_df,UK_df,how ='outer')

# %%
US_group1 = pd.merge(AU_IN,US_df,how ='outer')

# %%
group2 = pd.merge(US_group1,BA_FR,how ='outer')

# %%
group3= pd.merge(HO_JA,MA_SA,how ='outer')

# %%
group2_3 = pd.merge(group2,group3,how ='outer')

# %%
TA_UK_group_2_3 = pd.merge(TA_UK,group2_3,how ='outer')

# %%
TA_UK_group_2_3["Country"].value_counts()
# Out:
# Australia       50
# US              50
# South Africa    50
# France          50
# Taiwan          50
# India           50
# UK              50
# HongKong        50
# Malaysia        50
# Brazil          50
# Japan           50
# Name: Country, dtype: int64

# %%
TA_UK_group_2_3.to_csv("CSV_Output/11_country.csv")
